# %%
import pandas as pd

# 📄 Absolute path to the CSV file
csv_path = r"C:\Users\kopil\OneDrive\Рабочий стол\Projects\Additive_lab_robots\RaTSiF\data\framework\data\sensor\points\2025-04-15_17-43-22_points_694020.csv"

# 📥 Load the data
df = pd.read_csv(csv_path)

# 🖨 Check
print(f"✅ Points loaded: {len(df)}")
df.head()
# Out:
# ✅ Points loaded: 694020
#          X        Y        Z
# 0  1885.72  323.853 -52.5201
# 1  1885.71  323.912 -52.5371
# 2  1885.74  323.992 -52.4593
# 3  1885.72  324.037 -52.5426
# 4  1885.72  324.096 -52.5586

# %%
# STEP 2: Z-axis outlier removal (within the 90% range)
z_low = df['Z'].quantile(0.05)
z_high = df['Z'].quantile(0.99)

print(f'🔍 Z range for filtering: {z_low:.2f} — {z_high:.2f}')

# Apply filtering
df_clean_z = df[(df['Z'] >= z_low) & (df['Z'] <= z_high)].copy()
print(f'✅ Points remaining after Z filtering: {len(df_clean_z)}')
# Out:
# 🔍 Z range for filtering: -42.35 — -31.16
# ✅ Points remaining after Z filtering: 652386

# %%
# STEP 3: ROI filtering by Y and X (central region)

x_min, x_max = df_clean_z['X'].quantile([0.3, 0.9])
y_min, y_max = df_clean_z['Y'].quantile([0.367, 0.495])
z_min, z_max = df_clean_z['Z'].quantile([0.6, 0.999])

print(f'🔍 ROI Z range: {z_min:.2f} — {z_max:.2f}')
print(f'🔍 ROI X range: {x_min:.2f} — {x_max:.2f}')
print(f'🔍 ROI Y range: {y_min:.2f} — {y_max:.2f}')

df_clean_roi = df_clean_z[
    (df_clean_z['X'] >= x_min) & (df_clean_z['X'] <= x_max) &
    (df_clean_z['Y'] >= y_min) & (df_clean_z['Y'] <= y_max) &
    (df_clean_z['Z'] >= z_min) & (df_clean_z['Z'] <= z_max)
].copy()

print(f'✅ Points remaining after ROI filtering: {len(df_clean_roi)}')
# Out:
# 🔍 ROI Z range: -41.67 — -31.21
# 🔍 ROI X range: 1819.05 — 1874.29
# 🔍 ROI Y range: 348.98 — 356.71
# ✅ Points remaining after ROI filtering: 22965

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN

df_input = df_clean_roi.copy()

# 📌 Clustering by Z-axis
z_vals = df_input[['Z']].values
db = DBSCAN(eps=0.35, min_samples=30)
df_input['layer_id_3MethodDBSCAN'] = db.fit_predict(z_vals)

# ❌ Remove noise points
df_input = df_input[df_input['layer_id_3MethodDBSCAN'] != -1].copy()

# 🔢 Renumber layers starting from 1 using median Z
centers = df_input.groupby('layer_id_3MethodDBSCAN')['Z'].median()
sorted_idx = np.argsort(centers)
mapping = {old: new + 1 for new, old in enumerate(sorted_idx)}  # 👈 start from 1
df_input['layer_id_3MethodDBSCAN'] = df_input['layer_id_3MethodDBSCAN'].map(mapping)

# 📊 Layer statistics
print("📊 Number of points in each layer:")
for lid in sorted(df_input['layer_id_3MethodDBSCAN'].unique()):
    count = (df_input['layer_id_3MethodDBSCAN'] == lid).sum()
    print(f"  - Layer {lid}: {count} points")

print(f"\n✅ Total number of points after DBSCAN: {len(df_input)}")
# Out:
# 📊 Number of points in each layer:
#   - Layer 1: 22965 points
#
# ✅ Total number of points after DBSCAN: 22965

# %%
import plotly.graph_objs as go

# Unique global layers
unique_layers = sorted(df_input['layer_id_3MethodDBSCAN'].unique())  # global_layer_id

# 🎯 Points for each layer
data = []
for lid in unique_layers:
    subset = df_input[df_input['layer_id_3MethodDBSCAN'] == lid]
    trace = go.Scatter3d(
        x=subset['X'],
        y=subset['Y'],
        z=subset['Z'],
        mode='markers',
        marker=dict(size=2),
        name=f'Layer {lid}',
        visible=True if lid == 0 else False  # Show only the first layer by default
    )
    data.append(trace)

# 🔘 Buttons to switch between layers
buttons = []
for i, lid in enumerate(unique_layers):
    visible = [j == i for j in range(len(unique_layers))]
    buttons.append(dict(
        label=f"Layer {lid}",
        method="update",
        args=[{"visible": visible}, {"title": f"3D: Only Layer {lid}"}]
    ))

# Button to show all layers
buttons.insert(0, dict(
    label="All Layers",
    method="update",
    args=[{"visible": [True]*len(unique_layers)}, {"title": "3D: All Layers"}]
))

# ⚙️ Final chart assembly
fig = go.Figure(data=data)
fig.update_layout(
    updatemenus=[dict(
        type="dropdown",
        direction="down",
        showactive=True,
        x=1.05, y=1,
        buttons=buttons
    )],
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        aspectmode='data'
    ),
    title="3D: Only Layer 0 (default)"
)

# # 👁 Show
# fig.show()
pass

# %%
import os

# 📁 Path to the output directory next to this notebook
output_dir = "./output"
os.makedirs(output_dir, exist_ok=True)

# 📄 Path to the HTML file
output_path = os.path.join(output_dir, "3D_DBSCAN_layers.html")

# 💾 Save the figure
fig.write_html(output_path)
print(f"✅ Plot saved: {output_path}")
# Out:
# ✅ Plot saved: ./output\3D_DBSCAN_layers.html

# %%
# ✅ Combined 3D plot added (DBSCAN Method)

import os
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
import numpy as np

# 📁 Output folder
output_dir = "./output/plots_dbscan_layers"
os.makedirs(output_dir, exist_ok=True)

# 📌 Unique layers and color map (excluding noise if present)
unique_layers = sorted(df_input['layer_id_3MethodDBSCAN'].unique())
n_layers = len([gid for gid in unique_layers if gid != -1])  # exclude noise from color mapping
colormap = cm.get_cmap('tab20', n_layers)
layer_colors_dbscan = {}

color_index = 0
for layer_id in unique_layers:
    if layer_id == -1:
        layer_colors_dbscan[layer_id] = (0.2, 0.2, 0.2, 0.3)  # gray for noise
    else:
        layer_colors_dbscan[layer_id] = colormap(color_index)
        color_index += 1

# 📐 Fixed axis limits
x_min, x_max = df_input['X'].min(), df_input['X'].max()
y_min, y_max = df_input['Y'].min(), df_input['Y'].max()
z_min, z_max = df_input['Z'].min(), df_input['Z'].max()
aspect = [x_max - x_min, y_max - y_min, z_max - z_min]

# 📊 Individual 2D and 3D plots
for gid in unique_layers:
    layer = df_input[df_input['layer_id_3MethodDBSCAN'] == gid]
    print(f'🟢 Visualizing layer {gid} ({len(layer)} points)')

    # 2D projections
    fig, axs = plt.subplots(1, 3, figsize=(18, 5))

    axs[0].scatter(layer['X'], layer['Z'], s=1, color=layer_colors_dbscan[gid])
    axs[0].set_title(f'Layer {gid} — XZ')
    axs[0].set_xlabel('X')
    axs[0].set_ylabel('Z')
    axs[0].set_xlim(x_min, x_max)
    axs[0].set_ylim(z_min, z_max)
    axs[0].grid(True)

    axs[1].scatter(layer['Y'], layer['Z'], s=1, color=layer_colors_dbscan[gid])
    axs[1].set_title(f'Layer {gid} — YZ')
    axs[1].set_xlabel('Y')
    axs[1].set_ylabel('Z')
    axs[1].set_xlim(y_min, y_max)
    axs[1].set_ylim(z_min, z_max)
    axs[1].grid(True)

    axs[2].scatter(layer['X'], layer['Y'], s=1, color=layer_colors_dbscan[gid])
    axs[2].set_title(f'Layer {gid} — XY')
    axs[2].set_xlabel('X')
    axs[2].set_ylabel('Y')
    axs[2].set_xlim(x_min, x_max)
    axs[2].set_ylim(y_min, y_max)
    axs[2].grid(True)

    plt.tight_layout()
    plot_2d_path = os.path.join(output_dir, f"layer_{gid}_2D.png")
    fig.savefig(plot_2d_path, dpi=300)
    plt.close(fig)

    # 3D plot
    fig3d = plt.figure(figsize=(8, 6))
    ax = fig3d.add_subplot(111, projection='3d')
    ax.scatter(layer['X'], layer['Y'], layer['Z'], s=1, color=layer_colors_dbscan[gid])
    ax.set_title(f'Layer {gid} — 3D')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)
    ax.set_zlim(z_min, z_max)
    ax.set_box_aspect(aspect)
    ax.view_init(elev=30, azim=225)

    plot_3d_path = os.path.join(output_dir, f"layer_{gid}_3D.png")
    fig3d.savefig(plot_3d_path, dpi=300)
    plt.close(fig3d)

    print(f"💾 Saved: {plot_2d_path}, {plot_3d_path}")

# 🧩 Combined 3D plot for all layers
fig_all = plt.figure(figsize=(10, 8))
ax_all = fig_all.add_subplot(111, projection='3d')

for gid in unique_layers:
    layer = df_input[df_input['layer_id_3MethodDBSCAN'] == gid]
    ax_all.scatter(layer['X'], layer['Y'], layer['Z'], s=1, color=layer_colors_dbscan[gid], label=f'Layer {gid}')

ax_all.set_title('3D Layered Point Cloud View (DBSCAN)')
ax_all.set_xlabel('X')
ax_all.set_ylabel('Y')
ax_all.set_zlabel('Z')
ax_all.set_xlim(x_min, x_max)
ax_all.set_ylim(y_min, y_max)
ax_all.set_zlim(z_min, z_max)
ax_all.set_box_aspect(aspect)
ax_all.view_init(elev=30, azim=225)

plot_all_path = os.path.join(output_dir, "all_layers_3D.png")
fig_all.savefig(plot_all_path, dpi=300)
plt.close(fig_all)

print(f"📌 Combined 3D plot saved: {plot_all_path}")
# Out:
# C:\Users\kopil\AppData\Local\Temp\ipykernel_2088\3800348291.py:16: MatplotlibDeprecationWarning:
#
# The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
# 🟢 Visualizing layer 1 (22965 points)
# 💾 Saved: ./output/plots_dbscan_layers\layer_1_2D.png, ./output/plots_dbscan_layers\layer_1_3D.png
# 📌 Combined 3D plot saved: ./output/plots_dbscan_layers\all_layers_3D.png

# %%
import os

output_dir = r"C:\Users\kopil\OneDrive\Рабочий стол\Projects\Additive_lab_robots\RaTSiF\data\framework\src\4MethodClusterDBSCANAuto\output"
os.makedirs(output_dir, exist_ok=True)

output_path = os.path.join(output_dir, "4MethodClusterDBSCAN_result.csv")
df_input.to_csv(output_path, index=False)

print(f"✅ Saved: {output_path}")
# Out:
# ✅ Saved: C:\Users\kopil\OneDrive\Рабочий стол\Projects\Additive_lab_robots\RaTSiF\data\framework\src\4MethodClusterDBSCANAuto\output\4MethodClusterDBSCAN_result.csv
